# %%
import pandas as pd
import numpy as np 
import seaborn as sb
import matplotlib.pyplot as plt
import scipy as spy
import keras
from sklearn.metrics import accuracy_score, recall_score, confusion_matrix
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense,Dropout,Input
from keras.optimizers import Adam,RMSprop
df = pd.read_csv('winequality-white.csv')
# Out:
# 2021-08-11 09:39:28.295610: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-08-11 09:39:28.295626: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# Olhando abaixo, não temos nenhum valor N/A, então não precisamos tratar isso.

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
print(len(df))
df
# Out:
# 4898
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
df['quality'].value_counts()
# Out:
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: quality, dtype: int64

# %%
df.hist(figsize = (10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>],
#        [<AxesSubplot:title={'center':'residual sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free sulfur dioxide'}>],
#        [<AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>],
#        [<AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %% [markdown]
# Podemos ver acima que temos um desbalancemaneto na quantidade de amostras. Temos muitas regulares e poucas ruins e ótimas. Vamos usar uma técnica chamada SMOTE que consiste em fazer o oversampling das amostras minoritárias, deixando assim o dataset balanceado. Essa técnica foi descrita no artigo.

# %%
X=df.drop(columns=['quality'])
y=df['quality']

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE(k_neighbors=4)
X, y = oversample.fit_resample(X, y)

# %%
y.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# Pronto, agora temos todas as amostras em quantias iguais.

# %% [markdown]
# Agora temos que fazer o hot encoding para passar para a rede neural:

# %%
y =
# Out:
# 6

# %% [markdown]
# de correlação:

# %%
corr=df.corr()
plt.figure(figsize=(20,10))
sb.heatmap(corr,annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Também quero codificar essas qualidades numericamente:

# %% [markdown]
# Não utilizamos o álcool para o treinamento.

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20,random_state=21)
print('Formato do dataset de treinamento Xs:{}'.format(X_train.shape))
print('Formato do datasett de teste Xs:{}'.format(X_test.shape))
print('Formato do dataset de treino y:{}'.format(y_train.shape))
print('Formato do dataset de test y:{}'.format(y_test.shape))
y_train
# Out:
# Formato do dataset de treinamento Xs:(12308, 11)
# Formato do datasett de teste Xs:(3078, 11)
# Formato do dataset de treino y:(12308,)
# Formato do dataset de test y:(3078,)
# 12509    8
# 14261    9
# 13650    9
# 7263     4
# 2851     5
#         ..
# 48       6
# 8964     4
# 5944     3
# 5327     3
# 15305    9
# Name: quality, Length: 12308, dtype: int64

# %%
dimension = X_train.shape[1]
from keras import backend as K
def create_model():
    model = Sequential()
    model.add(Dense(10, input_dim=dimension, activation='sigmoid'))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                120
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 153
# Trainable params: 153
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_train, y_train, validation_data=(X_test, y_test),epochs=10, batch_size=10)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4394/1467714134.py in <module>
# ----> 1 history=model.fit(X_train, y_train, validation_data=(X_test, y_test),epochs=10, batch_size=10)
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     761     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     762     self._concrete_stateful_fn = (
# --> 763         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     764             *args, **kwds))
#     765
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048       args, kwargs = None, None
#    3049     with self._lock:
# -> 3050       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3051     return graph_function
#    3052
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443           self._function_cache.missed.add(call_context_key)
# -> 3444           graph_function = self._create_graph_function(args, kwargs)
#    3445           self._function_cache.primary[cache_key] = graph_function
#    3446
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3277     arg_names = base_arg_names + missing_arg_names
#    3278     graph_function = ConcreteFunction(
# -> 3279         func_graph_module.func_graph_from_py_func(
#    3280             self._name,
#    3281             self._python_function,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# ~/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     984           except Exception as e:  # pylint:disable=broad-except
#     985             if hasattr(e, "ag_error_metadata"):
# --> 986               raise e.ag_error_metadata.to_exception(e)
#     987             else:
#     988               raise
#
# ValueError: in user code:
#
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:855 train_function  *
#         return step_function(self, iterator)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:845 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1285 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2833 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:3608 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:838 run_step  **
#         outputs = model.train_step(data)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:796 train_step
#         loss = self.compiled_loss(
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/keras/engine/compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/keras/losses.py:155 __call__
#         losses = call_fn(y_true, y_pred)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/keras/losses.py:259 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:206 wrapper
#         return target(*args, **kwargs)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/keras/losses.py:1643 categorical_crossentropy
#         return backend.categorical_crossentropy(
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:206 wrapper
#         return target(*args, **kwargs)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:4862 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     /home/bufulin/.pyenv/versions/3.8.11/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py:1161 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 1) and (None, 3) are incompatible

# %% [markdown]
# <h2>avaliação do resultado: </h2>

# %%
mse_value, mae_value = model.evaluate(X_test, y_test, verbose=0)
print(mse_value)
y_pred = model.predict(X_test)
# Out:
# 0.0

# %%
#R2 score
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# -6.274306452881494

# %% [markdown]
# Outros testes com outro método

# %%
##SCALING THE DATA SET
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train =sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)
X_train
# Out:
# array([[-0.82011327, -0.47581927,  1.0587828 , ...,  0.36720572,
#         -0.71861487,  0.21981719],
#        [-0.24967568,  0.23598999, -0.26219583, ...,  1.15774788,
#          0.87160595,  1.22073207],
#        [ 2.03482921, -0.30094886,  1.13762308, ...,  0.01694768,
#         -0.24368285, -0.23586428],
#        ...,
#        [-0.12294395,  0.89897878,  0.60270096, ...,  0.59396545,
#         -0.97904973,  1.24239529],
#        [ 1.14470791,  0.26116727,  0.68365446, ..., -0.02166678,
#         -1.4624023 ,  1.10236136],
#        [-0.10616952,  0.26694596,  0.4860348 , ...,  0.69729907,
#         -1.00469619,  1.48066316]])

# %%
  from sklearn.ensemble import RandomForestClassifier
  forest=RandomForestClassifier(n_estimators=10, criterion = 'entropy', random_state=0)
  forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
  print('[5]RANDOM FOREST ACCURACY: ',forest.score(X_test,y_test))
# Out:
# [5]RANDOM FOREST ACCURACY:  0.827485380116959

# %%
x_pred = forest.predict(X_test)

# %%
x_pred
# Out:
# array([4, 4, 7, ..., 5, 7, 4])
